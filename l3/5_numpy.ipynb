# %% [markdown]
# # Image Processing with Numpy

# %%
# !pip install numpy imageio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 1.0 MB/s eta 0:00:0000:0100:010m
# ...

# %% [markdown]
# ## Getting The Data

# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt

# %% [markdown]
# we will use a logo image

# %%
img_url = "https://pbs.twimg.com/profile_images/1517584461017370624/DF3DpXUW_400x400.jpg"
logo = imageio.imread(img_url)
print(logo.shape)
# Out:
# /var/folders/rg/r1h2qhf502n6zsj0xdv9t3cw0000gn/T/ipykernel_35746/412312627.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   logo = imageio.imread(img_url)
# (398, 398, 3)

# %%
plt.imshow(logo)

# %%
for i in range(3):
    print(np.roll([1,2,3], i))
# Out:
# [1 2 3]
# [3 1 2]
# [2 3 1]

# %%
# plot three channels in a row using matplotlib
fig, axes = plt.subplots(1, 3, figsize=(10, 5))
for i, ax in enumerate(axes):
    ax.imshow(logo[:, :, i], cmap=plt.cm.gray)
    ax.set_title(f"Channel {i}")

# %%
# plot the logo in grayscale
plt.imshow(logo.mean(axis=2), cmap=plt.cm.gray)

# %%
# plot the logo with inverted colors
plt.imshow(1 - logo.mean(axis=2), cmap=plt.cm.gray)

# %%
# mirror the logo horizontally
plt.imshow(logo[:, ::-1])

# %%
# crop the logo 
plt.imshow(logo[50:150, 50:150])

# %%
# add some noise to the logo
plt.imshow(logo + np.random.randn(*logo.shape) * 255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# rotate the logo 30 degrees
plt.imshow(np.rot90(logo, 3))

# %%
# add 3 logos together
plt.imshow(np.concatenate([logo, logo, logo], axis=1))
